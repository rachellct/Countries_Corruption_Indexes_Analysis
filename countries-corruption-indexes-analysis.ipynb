# %% [markdown]
# ## Countries’ Corruption Indexes Analysis

# %% [markdown]
# ## I. Economic Theory
# <br/>
#
# * What is Market capitalization and Gross Domestic Product (GDP)?
# * Market capitalization reflects the value of a company
# * Market cap to GDP ratio
# * Corruption Perceptions Index (CPI)

# %%
# packages intended to use
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# read csv file using pandas package
gdp_data_uncleaned = pd.read_csv('/Users/rache/Downloads/files/gdp_data.csv')
gdp_data_uncleaned.set_index('Country Name', inplace=True)
gdp_data_uncleaned = gdp_data_uncleaned.iloc[:, 3:]
gdp_data_uncleaned.head()
# Out:
#                      1960         1961         1962         1963         1964  \
# Country Name
# Aruba                 NaN          NaN          NaN          NaN          NaN
# Afghanistan   537777811.1  548888895.6  546666677.8  751111191.1  800000044.4
# Angola                NaN          NaN          NaN          NaN          NaN
# Albania               NaN          NaN          NaN          NaN          NaN
# Andorra               NaN          NaN          NaN          NaN          NaN
#
#                       1965          1966          1967          1968  \
# Country Name
# Aruba                  NaN           NaN           NaN           NaN
# Afghanistan   1.006667e+09  1.400000e+09  1.673333e+09  1.373333e+09
# Angola                 NaN           NaN           NaN           NaN
# Albania                NaN           NaN           NaN           NaN
# Andorra                NaN           NaN           NaN           NaN
#
#                       1969  ...          2011          2012          2013  \
# Country Name                ...
# Aruba                  NaN  ...  2.549721e+09  2.534637e+09  2.701676e+09
# Afghanistan   1.408889e+09  ...  1.780429e+10  2.000160e+10  2.056107e+10
# Angola                 NaN  ...  1.117900e+11  1.280530e+11  1.367100e+11
# Albania                NaN  ...  1.289077e+10  1.231983e+10  1.277622e+10
# Andorra                NaN  ...  3.629204e+09  3.188809e+09  3.193704e+09
#
#                       2014          2015          2016          2017  \
# Country Name
# Aruba         2.765363e+09  2.919553e+09  2.965922e+09  3.056425e+09
# Afghanistan   2.048489e+10  1.990711e+10  1.801775e+10  1.886995e+10
# Angola        1.457120e+11  1.161940e+11  1.011240e+11  1.221240e+11
# Albania       1.322814e+10  1.138685e+10  1.186120e+10  1.301969e+10
# Andorra       3.271808e+09  2.789870e+09  2.896679e+09  3.000181e+09
#
#                       2018          2019  2020
# Country Name
# Aruba                  NaN           NaN   NaN
# Afghanistan   1.835388e+10  1.929110e+10   NaN
# Angola        1.013530e+11  8.881570e+10   NaN
# Albania       1.514702e+10  1.527918e+10   NaN
# Andorra       3.218316e+09  3.154058e+09   NaN
#
# [5 rows x 61 columns]

# %%
# read csv file using pandas package
market_cap_data_uncleaned = pd.read_csv('/Users/rache/Downloads/files/market_cap_usd.csv')
market_cap_data_uncleaned.set_index('Country Name', inplace=True)
market_cap_data_uncleaned = market_cap_data_uncleaned.iloc[:, 3:]
market_cap_data_uncleaned.sort_values('2019', ascending=False)
# Out:
#                      1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# Country Name
# East Asia & Pacific   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# IDA & IBRD total      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# IBRD only             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Low & middle income   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Middle income         NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# Samoa                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Kosovo                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                      1969  ...          2011          2012          2013  \
# Country Name               ...
# East Asia & Pacific   NaN  ...  1.377050e+13  1.573810e+13  1.736860e+13
# IDA & IBRD total      NaN  ...  1.036160e+13  1.161470e+13  1.154820e+13
# IBRD only             NaN  ...  1.021320e+13  1.151490e+13  1.141030e+13
# Low & middle income   NaN  ...  9.900700e+12  1.110710e+13  1.103880e+13
# Middle income         NaN  ...  9.900700e+12  1.110710e+13  1.103880e+13
# ...                   ...  ...           ...           ...           ...
# Samoa                 NaN  ...           NaN           NaN           NaN
# Kosovo                NaN  ...           NaN           NaN           NaN
# Yemen, Rep.           NaN  ...           NaN           NaN           NaN
# Zambia                NaN  ...  3.184470e+09           NaN           NaN
# Zimbabwe              NaN  ...           NaN           NaN           NaN
#
#                              2014          2015          2016          2017  \
# Country Name
# East Asia & Pacific  1.950630e+13  2.161100e+13  2.117260e+13  2.657260e+13
# IDA & IBRD total     1.325330e+13  1.427330e+13  1.441970e+13  1.777650e+13
# IBRD only            1.311710e+13  1.415720e+13  1.422760e+13  1.765310e+13
# Low & middle income  1.281180e+13  1.390960e+13  1.403060e+13  1.723680e+13
# Middle income        1.281180e+13  1.390960e+13  1.403060e+13  1.723680e+13
# ...                           ...           ...           ...           ...
# Samoa                         NaN           NaN           NaN           NaN
# Kosovo                        NaN           NaN           NaN           NaN
# Yemen, Rep.                   NaN           NaN           NaN           NaN
# Zambia                        NaN           NaN           NaN           NaN
# Zimbabwe                      NaN           NaN           NaN           NaN
#
#                              2018          2019  2020
# Country Name
# East Asia & Pacific  2.171880e+13  2.382020e+13   NaN
# IDA & IBRD total     1.423380e+13  1.677690e+13   NaN
# IBRD only            1.412490e+13  1.670470e+13   NaN
# Low & middle income  1.378040e+13  1.635010e+13   NaN
# Middle income        1.378040e+13  1.634690e+13   NaN
# ...                           ...           ...   ...
# Samoa                         NaN           NaN   NaN
# Kosovo                        NaN           NaN   NaN
# Yemen, Rep.                   NaN           NaN   NaN
# Zambia                        NaN           NaN   NaN
# Zimbabwe                      NaN           NaN   NaN
#
# [264 rows x 61 columns]

# %% [markdown]
# ## II. Data and Summary Statistics

# %%
market_cap_to_gdp = market_cap_data_uncleaned.div(gdp_data_uncleaned)
market_cap_to_gdp.sort_values('2018', ascending=False, inplace=True)
market_cap_to_gdp.head(20)
market_cap_to_gdp.describe
# Out:
# <bound method NDFrame.describe of                       1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# Country Name
# Hong Kong SAR, China   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# South Africa           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Switzerland            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Singapore              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United States          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# Samoa                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Kosovo                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                       1969  ...      2011       2012       2013       2014  \
# Country Name                ...
# Hong Kong SAR, China   NaN  ...  9.086168  10.783082  11.247057  11.092572
# South Africa           NaN  ...  1.894815   2.290304   2.570168   2.661492
# Switzerland            NaN  ...  1.557392   1.846345   2.237750   2.108497
# Singapore              NaN  ...  2.141653   2.592720   2.420257   2.391071
# United States          NaN  ...  1.006312   1.152578   1.431944   1.502271
# ...                    ...  ...       ...        ...        ...        ...
# Samoa                  NaN  ...       NaN        NaN        NaN        NaN
# Kosovo                 NaN  ...       NaN        NaN        NaN        NaN
# Yemen, Rep.            NaN  ...       NaN        NaN        NaN        NaN
# Zambia                 NaN  ...  0.135743        NaN        NaN        NaN
# Zimbabwe               NaN  ...       NaN        NaN        NaN        NaN
#
#                            2015      2016       2017       2018       2019  \
# Country Name
# Hong Kong SAR, China  10.294230  9.952811  12.748971  10.559170  13.396416
# South Africa           2.317054  3.210047   3.521573   2.349590   3.005816
# Switzerland            2.234846  2.090483   2.480329   2.043790   2.609155
# Singapore              2.077752  2.009804   2.302838   1.841441   1.874067
# United States          1.375468  1.461512   1.645578   1.478912        NaN
# ...                         ...       ...        ...        ...        ...
# Samoa                       NaN       NaN        NaN        NaN        NaN
# Kosovo                      NaN       NaN        NaN        NaN        NaN
# Yemen, Rep.                 NaN       NaN        NaN        NaN        NaN
# Zambia                      NaN       NaN        NaN        NaN        NaN
# Zimbabwe                    NaN       NaN        NaN        NaN        NaN
#
#                       2020
# Country Name
# Hong Kong SAR, China   NaN
# South Africa           NaN
# Switzerland            NaN
# Singapore              NaN
# United States          NaN
# ...                    ...
# Samoa                  NaN
# Kosovo                 NaN
# Yemen, Rep.            NaN
# Zambia                 NaN
# Zimbabwe               NaN
#
# [264 rows x 61 columns]>

# %%
df = pd.read_csv('/Users/rache/Downloads/files/index.csv')
df.head(50)
# Out:
#     CPI Rank                           Country Country Code  \
# 0          1                       New Zealand          NZL
# 1          1                           Denmark          DNK
# 2          3                           Finland          FIN
# 3          4                            Sweden          SWE
# 4          5                       Switzerland          CHE
# 5          6                            Norway          NOR
# 6          7                         Singapore          SGP
# 7          8                       Netherlands          NLD
# 8          9                            Canada          CAN
# 9         10                           Germany          DEU
# 10        10                        Luxembourg          LUX
# 11        10                    United Kingdom          GBR
# 12        13                         Australia          AUS
# 13        14                           Iceland          ISL
# 14        15                         Hong Kong          HKG
# 15        15                           Belgium          BEL
# 16        17                           Austria          AUT
# 17        18      The United States of America          USA
# 18        19                           Ireland          IRL
# 19        20                             Japan          JPN
# 20        21                           Uruguay          URY
# 21        22                           Estonia          EST
# 22        23                            France          FRA
# 23        24                           Bahamas          BHS
# 24        24                             Chile          CHL
# 25        24              United Arab Emirates          ARE
# 26        27                            Bhutan          BTN
# 27        28                            Israel          ISR
# 28        29                            Poland          POL
# 29        29                          Portugal          PRT
# 30        31                          Barbados          BRB
# 31        31                            Taiwan          TWN
# 32        31                             Qatar          QAT
# 33        31                          Slovenia          SVN
# 34        35                       Saint Lucia          LCA
# 35        35  Saint Vincent and The Grenadines          VCT
# 36        35                          Botswana          BWA
# 37        38                          Dominica          DMA
# 38        38                        Cape Verde          CPV
# 39        38                         Lithuania          LTU
# 40        41                        Costa Rica          CRI
# 41        41                            Brunei          BRN
# 42        41                             Spain          ESP
# 43        44                           Georgia          GEO
# 44        44                            Latvia          LVA
# 45        46                           Grenada          GRD
# 46        47                            Cyprus          CYP
# 47        47                    Czech Republic          CZE
# 48        47                             Malta          MLT
# 49        50                         Mauritius          MUS
#
#                           Region  Corruption Perceptions Index (CPI)  \
# 0                   Asia Pacific                                  90
# 1        Europe and Central Asia                                  90
# 2        Europe and Central Asia                                  89
# 3        Europe and Central Asia                                  88
# 4        Europe and Central Asia                                  86
# 5        Europe and Central Asia                                  85
# 6                   Asia Pacific                                  84
# 7        Europe and Central Asia                                  83
# 8                       Americas                                  82
# 9        Europe and Central Asia                                  81
# 10       Europe and Central Asia                                  81
# 11       Europe and Central Asia                                  81
# 12                  Asia Pacific                                  79
# 13       Europe and Central Asia                                  78
# 14                  Asia Pacific                                  77
# 15       Europe and Central Asia                                  77
# 16       Europe and Central Asia                                  75
# 17                      Americas                                  74
# 18       Europe and Central Asia                                  73
# 19                  Asia Pacific                                  72
# 20                      Americas                                  71
# 21       Europe and Central Asia                                  70
# 22       Europe and Central Asia                                  69
# 23                      Americas                                  66
# 24                      Americas                                  66
# 25  Middle East and North Africa                                  66
# 26                  Asia Pacific                                  65
# 27  Middle East and North Africa                                  64
# 28       Europe and Central Asia                                  62
# 29       Europe and Central Asia                                  62
# 30                      Americas                                  61
# 31                  Asia Pacific                                  61
# 32  Middle East and North Africa                                  61
# 33       Europe and Central Asia                                  61
# 34                      Americas                                  60
# 35                      Americas                                  60
# 36            Sub-Saharan Africa                                  60
# 37                      Americas                                  59
# 38            Sub-Saharan Africa                                  59
# 39       Europe and Central Asia                                  59
# 40                      Americas                                  58
# 41                  Asia Pacific                                  58
# 42       Europe and Central Asia                                  58
# 43       Europe and Central Asia                                  57
# 44       Europe and Central Asia                                  57
# 45                      Americas                                  56
# 46       Europe and Central Asia                                  55
# 47       Europe and Central Asia                                  55
# 48       Europe and Central Asia                                  55
# 49            Sub-Saharan Africa                                  54
#
#     Standard Error  Lower Confidence Interval  Upper Confidence Interval  \
# 0             2.56                         86                         94
# 1             2.46                         86                         94
# 2             1.46                         87                         92
# 3             1.33                         85                         90
# 4             1.57                         83                         89
# 5             1.85                         82                         88
# 6             2.35                         81                         88
# 7             2.32                         79                         87
# 8             2.03                         79                         85
# 9             2.73                         77                         86
# 10            1.96                         78                         84
# 11            2.12                         77                         84
# 12            1.27                         77                         81
# 13            3.81                         71                         84
# 14            2.62                         73                         82
# 15            1.55                         74                         79
# 16            1.36                         73                         77
# 17            3.15                         69                         80
# 18            4.31                         66                         80
# 19            3.02                         67                         77
# 20            2.68                         66                         75
# 21            2.16                         66                         73
# 22            2.97                         64                         74
# 23            5.20                         57                         74
# 24            2.65                         61                         70
# 25            5.70                         56                         75
# 26            2.12                         62                         69
# 27            2.27                         60                         68
# 28            1.77                         59                         65
# 29            2.58                         58                         66
# 30            6.91                         50                         73
# 31            3.79                         55                         67
# 32            7.02                         49                         72
# 33            2.44                         57                         65
# 34            6.80                         49                         71
# 35            1.66                         57                         63
# 36            3.10                         55                         66
# 37            0.85                         58                         60
# 38            5.72                         50                         68
# 39            1.36                         57                         61
# 40            3.17                         53                         63
# 41            8.85                         43                         72
# 42            4.09                         51                         65
# 43            3.61                         51                         63
# 44            2.96                         52                         62
# 45            4.63                         48                         63
# 46            5.94                         46                         65
# 47            2.24                         51                         59
# 48            1.39                         53                         58
# 49            2.14                         50                         57
#
#     World Bank CPIA  World Economic Forum EOS  ...  \
# 0               NaN                      90.0  ...
# 1               NaN                      85.0  ...
# 2               NaN                      91.0  ...
# 3               NaN                      86.0  ...
# 4               NaN                      80.0  ...
# 5               NaN                      80.0  ...
# 6               NaN                      88.0  ...
# 7               NaN                      82.0  ...
# 8               NaN                      73.0  ...
# 9               NaN                      67.0  ...
# 10              NaN                      85.0  ...
# 11              NaN                      80.0  ...
# 12              NaN                      80.0  ...
# 13              NaN                      85.0  ...
# 14              NaN                      82.0  ...
# 15              NaN                      73.0  ...
# 16              NaN                      73.0  ...
# 17              NaN                      65.0  ...
# 18              NaN                      83.0  ...
# 19              NaN                      78.0  ...
# 20              NaN                      68.0  ...
# 21              NaN                      76.0  ...
# 22              NaN                      69.0  ...
# 23              NaN                       NaN  ...
# 24              NaN                      64.0  ...
# 25              NaN                      86.0  ...
# 26             69.0                      59.0  ...
# 27              NaN                      69.0  ...
# 28              NaN                      56.0  ...
# 29              NaN                      59.0  ...
# 30              NaN                      48.0  ...
# 31              NaN                      68.0  ...
# 32              NaN                      82.0  ...
# 33              NaN                      58.0  ...
# 34             69.0                       NaN  ...
# 35             58.0                       NaN  ...
# 36              NaN                      52.0  ...
# 37             58.0                       NaN  ...
# 38             69.0                      49.0  ...
# 39              NaN                      56.0  ...
# 40              NaN                      46.0  ...
# 41              NaN                      61.0  ...
# 42              NaN                      51.0  ...
# 43              NaN                      68.0  ...
# 44              NaN                      48.0  ...
# 45             58.0                       NaN  ...
# 46              NaN                      49.0  ...
# 47              NaN                      46.0  ...
# 48              NaN                      54.0  ...
# 49              NaN                      53.0  ...
#
#     African Development Bank CPIA  IMD World Competitiveness Yearbook  \
# 0                             NaN                                95.0
# 1                             NaN                                98.0
# 2                             NaN                                94.0
# 3                             NaN                                86.0
# 4                             NaN                                88.0
# 5                             NaN                                83.0
# 6                             NaN                                91.0
# 7                             NaN                                89.0
# 8                             NaN                                85.0
# 9                             NaN                                85.0
# 10                            NaN                                81.0
# 11                            NaN                                80.0
# 12                            NaN                                81.0
# 13                            NaN                                80.0
# 14                            NaN                                87.0
# 15                            NaN                                79.0
# 16                            NaN                                74.0
# 17                            NaN                                74.0
# 18                            NaN                                83.0
# 19                            NaN                                74.0
# 20                            NaN                                 NaN
# 21                            NaN                                66.0
# 22                            NaN                                73.0
# 23                            NaN                                 NaN
# 24                            NaN                                54.0
# 25                            NaN                                81.0
# 26                            NaN                                 NaN
# 27                            NaN                                64.0
# 28                            NaN                                60.0
# 29                            NaN                                51.0
# 30                            NaN                                 NaN
# 31                            NaN                                65.0
# 32                            NaN                                80.0
# 33                            NaN                                46.0
# 34                            NaN                                 NaN
# 35                            NaN                                 NaN
# 36                            NaN                                 NaN
# 37                            NaN                                 NaN
# 38                            NaN                                 NaN
# 39                            NaN                                53.0
# 40                            NaN                                 NaN
# 41                            NaN                                 NaN
# 42                            NaN                                38.0
# 43                            NaN                                 NaN
# 44                            NaN                                45.0
# 45                            NaN                                 NaN
# 46                            NaN                                 NaN
# 47                            NaN                                47.0
# 48                            NaN                                 NaN
# 49                            NaN                                 NaN
#
#     Bertelsmann Foundation Sustainable Governance Index  \
# 0                                                99.0
# 1                                                99.0
# 2                                                90.0
# 3                                                90.0
# 4                                                90.0
# 5                                                80.0
# 6                                                 NaN
# 7                                                71.0
# 8                                                80.0
# 9                                                80.0
# 10                                               80.0
# 11                                               80.0
# 12                                               80.0
# 13                                               61.0
# 14                                                NaN
# 15                                               80.0
# 16                                               80.0
# 17                                               90.0
# 18                                               71.0
# 19                                               52.0
# 20                                                NaN
# 21                                               80.0
# 22                                               52.0
# 23                                                NaN
# 24                                               61.0
# 25                                                NaN
# 26                                                NaN
# 27                                               61.0
# 28                                               71.0
# 29                                               71.0
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                               61.0
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                               61.0
# 40                                                NaN
# 41                                                NaN
# 42                                               61.0
# 43                                                NaN
# 44                                               71.0
# 45                                                NaN
# 46                                               42.0
# 47                                               52.0
# 48                                               52.0
# 49                                                NaN
#
#     World Justice Project Rule of Law Index  \
# 0                                      79.0
# 1                                      85.0
# 2                                      85.0
# 3                                      85.0
# 4                                       NaN
# 5                                      84.0
# 6                                      85.0
# 7                                      82.0
# 8                                      79.0
# 9                                      79.0
# 10                                      NaN
# 11                                     80.0
# 12                                     78.0
# 13                                      NaN
# 14                                     77.0
# 15                                     74.0
# 16                                     79.0
# 17                                     72.0
# 18                                      NaN
# 19                                     75.0
# 20                                     72.0
# 21                                     70.0
# 22                                     69.0
# 23                                     62.0
# 24                                     65.0
# 25                                     73.0
# 26                                      NaN
# 27                                      NaN
# 28                                     66.0
# 29                                     68.0
# 30                                     65.0
# 31                                      NaN
# 32                                      NaN
# 33                                     59.0
# 34                                     65.0
# 35                                     63.0
# 36                                     55.0
# 37                                     61.0
# 38                                      NaN
# 39                                      NaN
# 40                                     61.0
# 41                                      NaN
# 42                                     65.0
# 43                                     61.0
# 44                                      NaN
# 45                                     62.0
# 46                                      NaN
# 47                                     62.0
# 48                                      NaN
# 49                                      NaN
#
#     PRS International Country Risk Guide  Varities of Democracy Project  \
# 0                                   93.0                            NaN
# 1                                   93.0                            NaN
# 2                                   93.0                            NaN
# 3                                   93.0                            NaN
# 4                                   85.0                            NaN
# 5                                   93.0                            NaN
# 6                                   76.0                            NaN
# 7                                   85.0                            NaN
# 8                                   85.0                            NaN
# 9                                   85.0                            NaN
# 10                                  85.0                            NaN
# 11                                  85.0                            NaN
# 12                                  76.0                            NaN
# 13                                  85.0                            NaN
# 14                                  67.0                            NaN
# 15                                  76.0                            NaN
# 16                                  76.0                            NaN
# 17                                  76.0                           69.0
# 18                                  76.0                            NaN
# 19                                  76.0                            NaN
# 20                                  76.0                            NaN
# 21                                  67.0                           69.0
# 22                                  76.0                            NaN
# 23                                  76.0                            NaN
# 24                                  76.0                            NaN
# 25                                  67.0                            NaN
# 26                                   NaN                           64.0
# 27                                  58.0                            NaN
# 28                                  58.0                           66.0
# 29                                  67.0                           67.0
# 30                                   NaN                            NaN
# 31                                  50.0                           50.0
# 32                                  67.0                           39.0
# 33                                  58.0                           67.0
# 34                                   NaN                            NaN
# 35                                   NaN                            NaN
# 36                                  67.0                            NaN
# 37                                   NaN                            NaN
# 38                                   NaN                            NaN
# 39                                  58.0                           64.0
# 40                                  50.0                           69.0
# 41                                  41.0                            NaN
# 42                                  58.0                            NaN
# 43                                   NaN                           65.0
# 44                                  50.0                           67.0
# 45                                   NaN                            NaN
# 46                                  67.0                            NaN
# 47                                  50.0                            NaN
# 48                                  58.0                            NaN
# 49                                   NaN                            NaN
#
#     Economist Intelligence Unit Country Ratings  \
# 0                                          90.0
# 1                                          90.0
# 2                                          90.0
# 3                                          90.0
# 4                                          90.0
# 5                                          90.0
# 6                                          90.0
# 7                                          90.0
# 8                                          90.0
# 9                                          90.0
# 10                                         72.0
# 11                                         90.0
# 12                                         72.0
# 13                                         72.0
# 14                                         72.0
# 15                                         72.0
# 16                                         72.0
# 17                                         90.0
# 18                                         54.0
# 19                                         72.0
# 20                                         72.0
# 21                                         54.0
# 22                                         72.0
# 23                                          NaN
# 24                                         72.0
# 25                                         54.0
# 26                                          NaN
# 27                                         72.0
# 28                                         54.0
# 29                                         54.0
# 30                                          NaN
# 31                                         54.0
# 32                                         72.0
# 33                                         54.0
# 34                                          NaN
# 35                                          NaN
# 36                                         72.0
# 37                                          NaN
# 38                                          NaN
# 39                                         54.0
# 40                                         54.0
# 41                                          NaN
# 42                                         72.0
# 43                                          NaN
# 44                                         54.0
# 45                                          NaN
# 46                                         72.0
# 47                                         54.0
# 48                                         54.0
# 49                                         54.0
#
#     Freedom House Nations in Transit Ratings  PERC Asia Risk Guide  Sources
# 0                                        NaN                   NaN        7
# 1                                        NaN                   NaN        7
# 2                                        NaN                   NaN        7
# 3                                        NaN                   NaN        7
# 4                                        NaN                   NaN        6
# 5                                        NaN                   NaN        7
# 6                                        NaN                  89.0        8
# 7                                        NaN                   NaN        7
# 8                                        NaN                   NaN        7
# 9                                        NaN                   NaN        7
# 10                                       NaN                   NaN        6
# 11                                       NaN                   NaN        7
# 12                                       NaN                  81.0        8
# 13                                       NaN                   NaN        6
# 14                                       NaN                  74.0        7
# 15                                       NaN                   NaN        7
# 16                                       NaN                   NaN        7
# 17                                       NaN                  64.0        9
# 18                                       NaN                   NaN        6
# 19                                       NaN                  78.0        8
# 20                                       NaN                   NaN        6
# 21                                      70.0                   NaN       10
# 22                                       NaN                   NaN        7
# 23                                       NaN                   NaN        3
# 24                                       NaN                   NaN        8
# 25                                       NaN                   NaN        7
# 26                                       NaN                   NaN        5
# 27                                       NaN                   NaN        6
# 28                                      59.0                   NaN       10
# 29                                       NaN                   NaN        8
# 30                                       NaN                   NaN        3
# 31                                       NaN                  51.0        8
# 32                                       NaN                   NaN        7
# 33                                      70.0                   NaN       10
# 34                                       NaN                   NaN        3
# 35                                       NaN                   NaN        3
# 36                                       NaN                   NaN        6
# 37                                       NaN                   NaN        3
# 38                                       NaN                   NaN        3
# 39                                      59.0                   NaN        9
# 40                                       NaN                   NaN        7
# 41                                       NaN                   NaN        3
# 42                                       NaN                   NaN        7
# 43                                      49.0                   NaN        6
# 44                                      65.0                   NaN        9
# 45                                       NaN                   NaN        3
# 46                                       NaN                   NaN        5
# 47                                      59.0                   NaN        9
# 48                                       NaN                   NaN        5
# 49                                       NaN                   NaN        4
#
# [50 rows x 22 columns]

# %%
# list of column names
market_cap_to_gdp.columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %% [markdown]
# ## III. Variables Descriptions
# <br/>
#
# * Corruption Perceptions Index (CPI)
# * Global Insight Country Risk Ratings
# * IMD World Competitiveness Yearbook
# * World Justice Project Rule of Law Index
# * Economist Intelligence Unit Country Ratings

# %%
market_cap_to_gdp.describe
# Out:
# <bound method NDFrame.describe of                       1960  1961  1962  1963  1964  1965  1966  1967  1968  \
# Country Name
# Hong Kong SAR, China   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# South Africa           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Switzerland            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Singapore              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# United States          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                    ...   ...   ...   ...   ...   ...   ...   ...   ...
# Samoa                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Kosovo                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Yemen, Rep.            NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zimbabwe               NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                       1969  ...      2011       2012       2013       2014  \
# Country Name                ...
# Hong Kong SAR, China   NaN  ...  9.086168  10.783082  11.247057  11.092572
# South Africa           NaN  ...  1.894815   2.290304   2.570168   2.661492
# Switzerland            NaN  ...  1.557392   1.846345   2.237750   2.108497
# Singapore              NaN  ...  2.141653   2.592720   2.420257   2.391071
# United States          NaN  ...  1.006312   1.152578   1.431944   1.502271
# ...                    ...  ...       ...        ...        ...        ...
# Samoa                  NaN  ...       NaN        NaN        NaN        NaN
# Kosovo                 NaN  ...       NaN        NaN        NaN        NaN
# Yemen, Rep.            NaN  ...       NaN        NaN        NaN        NaN
# Zambia                 NaN  ...  0.135743        NaN        NaN        NaN
# Zimbabwe               NaN  ...       NaN        NaN        NaN        NaN
#
#                            2015      2016       2017       2018       2019  \
# Country Name
# Hong Kong SAR, China  10.294230  9.952811  12.748971  10.559170  13.396416
# South Africa           2.317054  3.210047   3.521573   2.349590   3.005816
# Switzerland            2.234846  2.090483   2.480329   2.043790   2.609155
# Singapore              2.077752  2.009804   2.302838   1.841441   1.874067
# United States          1.375468  1.461512   1.645578   1.478912        NaN
# ...                         ...       ...        ...        ...        ...
# Samoa                       NaN       NaN        NaN        NaN        NaN
# Kosovo                      NaN       NaN        NaN        NaN        NaN
# Yemen, Rep.                 NaN       NaN        NaN        NaN        NaN
# Zambia                      NaN       NaN        NaN        NaN        NaN
# Zimbabwe                    NaN       NaN        NaN        NaN        NaN
#
#                       2020
# Country Name
# Hong Kong SAR, China   NaN
# South Africa           NaN
# Switzerland            NaN
# Singapore              NaN
# United States          NaN
# ...                    ...
# Samoa                  NaN
# Kosovo                 NaN
# Yemen, Rep.            NaN
# Zambia                 NaN
# Zimbabwe               NaN
#
# [264 rows x 61 columns]>

# %% [markdown]
# ### Equation
#
# Market cap to GDP ratio = a + bXi + cXi + dXi + eXi + fXi + ϵ
#
# ![image.png](attachment:e29d2526-338f-45b5-a4c8-d4a2f29edbd6.png)
#
# Where:
# * Corruption Perceptions Index (CPI) = bX1
# * Global Insight Country Risk Ratings = cX2
# * IMD World Competitiveness Yearbook = dX3
# * World Justice Project Rule of Law Index = eX4
# * Economist Intelligence Unit Country Ratings = fX5
# * Residual (error) = ϵ

# %%
#Original
from pandas import DataFrame
import statsmodels.api as sm

corruption_index_data = df.fillna(method='ffill')
corruption_index_data.rename(columns={'Country': 'Country Name'}, inplace=True)

merged_data = pd.merge(corruption_index_data, market_cap_to_gdp, how='inner', on=['Country Name'])
merged_data.set_index('Country Name', inplace=True)
merged_data.dropna(subset = ['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings','2017'],inplace=True)

x = merged_data[['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings']]
x = sm.add_constant(x) #adding a constant

y = market_cap_to_gdp
y = merged_data[['2017']]

model = sm.OLS(y, x).fit()
predictions = model.predict(x)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   2017   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     5.452
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):            0.00687
# Time:                        22:42:35   Log-Likelihood:                -49.782
# No. Observations:                  59   AIC:                             105.6
# Df Residuals:                      56   BIC:                             111.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -0.0537      0.232     -0.232      0.818      -0.518       0.411
# Corruption Perceptions Index (CPI)      0.0149      0.011      1.346      0.184      -0.007       0.037
# Global Insight Country Risk Ratings    -0.0013      0.010     -0.123      0.902      -0.022       0.020
# ==============================================================================
# Omnibus:                       60.340   Durbin-Watson:                   2.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.494
# Skew:                           2.807   Prob(JB):                     7.99e-87
# Kurtosis:                      14.392   Cond. No.                         244.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# !pip install linearmodels
# Out:
# Requirement already satisfied: linearmodels in c:\users\rache\anaconda3\lib\site-packages (4.27)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (0.4.3)
# Requirement already satisfied: Cython>=0.29.21 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (0.29.33)
# Requirement already satisfied: numpy>=1.16 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (1.23.5)
# Requirement already satisfied: pyhdfe>=0.1 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (0.1.2)
# Requirement already satisfied: setuptools-scm<7.0.0,>=6.4.2 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (6.4.2)
# Requirement already satisfied: property-cached>=1.6.3 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (1.6.4)
# Requirement already satisfied: scipy>=1.2 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (1.10.0)
# Requirement already satisfied: statsmodels>=0.11 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (0.13.5)
# Requirement already satisfied: formulaic~=0.3.2 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (0.3.4)
# Requirement already satisfied: pandas>=0.24 in c:\users\rache\anaconda3\lib\site-packages (from linearmodels) (1.5.3)
# Requirement already satisfied: interface-meta<2.0.0,>=1.2.0 in c:\users\rache\anaconda3\lib\site-packages (from formulaic~=0.3.2->linearmodels) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in c:\users\rache\anaconda3\lib\site-packages (from formulaic~=0.3.2->linearmodels) (1.14.1)
# Requirement already satisfied: astor>=0.8 in c:\users\rache\anaconda3\lib\site-packages (from formulaic~=0.3.2->linearmodels) (0.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rache\anaconda3\lib\site-packages (from pandas>=0.24->linearmodels) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\rache\anaconda3\lib\site-packages (from pandas>=0.24->linearmodels) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\rache\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (22.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\rache\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (2.0.1)
# Requirement already satisfied: setuptools in c:\users\rache\anaconda3\lib\site-packages (from setuptools-scm<7.0.0,>=6.4.2->linearmodels) (65.6.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\rache\anaconda3\lib\site-packages (from statsmodels>=0.11->linearmodels) (0.5.3)
# Requirement already satisfied: six in c:\users\rache\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.11->linearmodels) (1.16.0)

# %%
#COPY using another model 
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
import statsmodels.api as sm
from linearmodels import PanelOLS


corruption_index_data = df.fillna(method='ffill')
corruption_index_data.rename(columns={'Country': 'Country Name'}, inplace=True)

merged_data = pd.merge(corruption_index_data, market_cap_to_gdp, how='inner', on=['Country Name'])
merged_data.set_index('Country Name', inplace=True)
merged_data.dropna(subset = ['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings','2017'],inplace=True)

# exog_vars = ['Corruption Perceptions Index (CPI)', 'Global Insight Country Risk Ratings']
# exog = sm.add_constant(merged_data[exog_vars])

# merged2 = merged_data.rename(columns = {'2017': 'Year'}, inplace = False)


# mod = PanelOLS(y = merged2['Year'], x = merged2[['Corruption Perceptions Index (CPI)', 'Global Insight Country Risk Ratings']], time_effects=True)

# # mod = PooledOLS(merged2.Year, exog)
# pooled_res = mod.fit()
# print(pooled_res)

x = merged_data[['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings']]
x = sm.add_constant(x) #adding a constant

y = market_cap_to_gdp
y = merged_data[['2017']]

model = sm.OLS(y, x).fit()
predictions = model.predict(x)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   2017   R-squared:                       0.163
# Model:                            OLS   Adj. R-squared:                  0.133
# Method:                 Least Squares   F-statistic:                     5.452
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):            0.00687
# Time:                        22:43:22   Log-Likelihood:                -49.782
# No. Observations:                  59   AIC:                             105.6
# Df Residuals:                      56   BIC:                             111.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -0.0537      0.232     -0.232      0.818      -0.518       0.411
# Corruption Perceptions Index (CPI)      0.0149      0.011      1.346      0.184      -0.007       0.037
# Global Insight Country Risk Ratings    -0.0013      0.010     -0.123      0.902      -0.022       0.020
# ==============================================================================
# Omnibus:                       60.340   Durbin-Watson:                   2.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              396.494
# Skew:                           2.807   Prob(JB):                     7.99e-87
# Kurtosis:                      14.392   Cond. No.                         244.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Copy for adding more variables
from pandas import DataFrame
import statsmodels.api as sm

corruption_index_data = df.fillna(method='ffill')
corruption_index_data.rename(columns={'Country': 'Country Name'}, inplace=True)

merged_data = pd.merge(corruption_index_data, market_cap_to_gdp, how='inner', on=['Country Name'])
merged_data.set_index('Country Name', inplace=True)
merged_data.dropna(subset = ['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings','IMD World Competitiveness Yearbook','World Justice Project Rule of Law Index','Economist Intelligence Unit Country Ratings','2017'],inplace=True)

x = merged_data[['Corruption Perceptions Index (CPI)','Global Insight Country Risk Ratings','IMD World Competitiveness Yearbook','World Justice Project Rule of Law Index','Economist Intelligence Unit Country Ratings']]
x = sm.add_constant(x) #adding a constant

y = market_cap_to_gdp
y = merged_data[['2017']]

model = sm.OLS(y, x).fit()
predictions = model.predict(x)

print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   2017   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.166
# Method:                 Least Squares   F-statistic:                     3.309
# Date:                Thu, 23 Mar 2023   Prob (F-statistic):             0.0113
# Time:                        22:43:32   Log-Likelihood:                -47.015
# No. Observations:                  59   AIC:                             106.0
# Df Residuals:                      53   BIC:                             118.5
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# const                                           0.0152      0.231      0.066      0.948      -0.448       0.478
# Corruption Perceptions Index (CPI)             -0.0046      0.034     -0.136      0.893      -0.073       0.063
# Global Insight Country Risk Ratings             0.0029      0.012      0.246      0.807      -0.021       0.027
# IMD World Competitiveness Yearbook              0.0052      0.011      0.482      0.632      -0.017       0.027
# World Justice Project Rule of Law Index        -0.0127      0.015     -0.852      0.398      -0.043       0.017
# Economist Intelligence Unit Country Ratings     0.0219      0.011      1.981      0.053      -0.000       0.044
# ==============================================================================
# Omnibus:                       57.622   Durbin-Watson:                   2.236
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              371.713
# Skew:                           2.632   Prob(JB):                     1.92e-81
# Kurtosis:                      14.113   Cond. No.                         393.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## IV. Regression Model Results
# <br/>
#
# * We expect an average of 0.0152 increase in market cap to GDP ratio if other independent variables is constant.
# * Global Insight Country Ratings, World Competitive Yearbook, and EIU ratings have a positive effects on Market cap to GDP ratio
# * CPI and Rule of Law Index both have a negative effect on Market cap to GDP ratio

# %% [markdown]
# ## V. Conclusion
#
# R2 from the model was low (0.238) which means the independent variables are not explaining much in the change of Market cap to GDP ratio
